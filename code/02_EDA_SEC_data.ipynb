# %%
"""

EDA of TRAINING and VALIDATION DATA
SEC filings 2014-2018

Downloaded from Google Cloud and saved in local Postgres database

- amount of missing data points in SEC data
- records reported in non-USD


"""

# %%
import psycopg2 as pg
import pandas.io.sql as pd_sql
import pandas as pd
import numpy as np
import datetime

# %%
# Postgres info to connect

connection_args = {
    'host': 'localhost',  
    'dbname': 'bankruptcy',  
    'port': 5432          
}

connection = pg.connect(**connection_args)
connection.autocommit = True

# %%
# few fields pulled

query = """
SELECT distinct measure_tag
FROM sec_all_raw
WHERE  period_end_date < '2019-01-01' 
    and units = 'USD'

;
"""

sec_data = pd_sql.read_sql(query, connection)
sec_data.head()
# Out:
#                                   measure_tag
# 0                               NetIncomeLoss
# 1                    RepaymentsOfLongTermDebt
# 2  NetCashProvidedByUsedInInvestingActivities
# 3             DeferredIncomeTaxLiabilitiesNet
# 4                         OperatingIncomeLoss

# %%
len(sec_data)
# Out:
# 34

# %%
sec_data.tail()
# Out:
#                                    measure_tag
# 29            LiabilitiesAndStockholdersEquity
# 30                                    Revenues
# 31                       EarningsPerShareBasic
# 32  NetCashProvidedByUsedInOperatingActivities
# 33                                 GrossProfit

# %%
all_columns = sec_data.transpose()

# %%
all_columns
# Out:
#                         0                         1   \
# measure_tag  NetIncomeLoss  RepaymentsOfLongTermDebt
#
#                                                      2   \
# measure_tag  NetCashProvidedByUsedInInvestingActivities
#
#                                           3                    4   \
# measure_tag  DeferredIncomeTaxLiabilitiesNet  OperatingIncomeLoss
#
#                              5           6   \
# measure_tag  LiabilitiesCurrent  TotalAsset
#
#                                                             7             8   \
# measure_tag  LongTermDebtMaturitiesRepaymentsOfPrincipalInN...  LongTermDebt
#
#                  9   ...                               24  \
# measure_tag  Assets  ...  DeferredIncomeTaxExpenseBenefit
#
#                                                      25           26  \
# measure_tag  NetCashProvidedByUsedInFinancingActivities  Liabilities
#
#                            27                      28  \
# measure_tag  CommonStockValue  LongTermDebtNoncurrent
#
#                                            29        30  \
# measure_tag  LiabilitiesAndStockholdersEquity  Revenues
#
#                                 31  \
# measure_tag  EarningsPerShareBasic
#
#                                                      32           33
# measure_tag  NetCashProvidedByUsedInOperatingActivities  GrossProfit
#
# [1 rows x 34 columns]

# %%
#########

# %%
# Which companies are submitting filings with non-USD values

query = """
SELECT distinct company_name, units
FROM sec_all_raw
WHERE  period_end_date < '2019-01-01' 
    and units != 'USD'

;
"""

sec_data = pd_sql.read_sql(query, connection)
sec_data.head()
# Out:
#                           company_name units
# 0                 ALGAE DYNAMICS CORP.   CAD
# 1                      ALTIMMUNE, INC.   EUR
# 2                    AMC NETWORKS INC.   EUR
# 3  AMERICAN GRAPHITE TECHNOLOGIES INC.   CAD
# 4                BI-OPTIC VENTURES INC   CAD

# %%
len(sec_data)
# Out:
# 68

# %%
sec_data.tail()
# Out:
#                 company_name units
# 63  UNIVERSAL BIOSENSORS INC   AUD
# 64      VISCOUNT SYSTEMS INC   CAD
# 65         VYCOR MEDICAL INC   EUR
# 66       WABCO HOLDINGS INC.   EUR
# 67         YOSEN GROUP, INC.   CNY

# %%
## After researching, found non-U.S. public companies can and do file the 10-K
## Though supposed to use a different SEC form 20-F
## there doesn't seem to be a requirement that they not use the 10-K

## will remove the companies with non-USD units from data set

# %%
#################

# %%
#Revenue can be in a few different fields, may need to pull more data from Google Cloud

query = """
SELECT company_name, period_end_date, measure_tag, value
FROM sec_all_raw
WHERE  period_end_date < '2019-01-01' 
    and units = 'USD'
    and measure_tag in ('ProfitLoss', 'Revenues', 'SalesRevenueNet', 'Assets', 'GrossProfit')

;
"""

sec_data = pd_sql.read_sql(query, connection)
sec_data.head()
# Out:
#                      company_name period_end_date measure_tag         value
# 0  ADAMS RESOURCES & ENERGY, INC.      2011-12-31      Assets  3.788400e+08
# 1  ADAMS RESOURCES & ENERGY, INC.      2012-12-31      Assets  4.195010e+08
# 2  ADAMS RESOURCES & ENERGY, INC.      2013-12-31      Assets  4.480820e+08
# 3  ADAMS RESOURCES & ENERGY, INC.      2011-12-31    Revenues  3.038737e+09
# 4  ADAMS RESOURCES & ENERGY, INC.      2012-03-31    Revenues  8.759050e+08

# %%
pivoted = sec_data.pivot_table(index=['company_name', 'period_end_date'], columns= 'measure_tag',
                                values='value').reset_index()

# %%
over_100 = pivoted[pivoted['Assets']>= 100000000]

# %%
len(over_100)
# Out:
# 28509

# %%
over_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28509 entries, 4 to 110987
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_name     28509 non-null  object
#  1   period_end_date  28509 non-null  datetime64[ns]
#  2   Assets           28509 non-null  float64
#  3   GrossProfit      11284 non-null  float64
#  4   ProfitLoss       13700 non-null  float64
#  5   Revenues         13871 non-null  float64
#  6   SalesRevenueNet  8204 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.7+ MB

# %%
over_100[over_100['company_name'] == 'ALPHABET INC.']
# Out:
# measure_tag   company_name period_end_date        Assets  GrossProfit  \
# 4639         ALPHABET INC.      2016-12-31  1.674970e+11          NaN
# 4640         ALPHABET INC.      2017-12-31  1.972950e+11          NaN
# 4641         ALPHABET INC.      2018-12-31  2.327920e+11          NaN
# 4642         ALPHABET INC.      2014-12-31  1.291870e+11          NaN
# 4643         ALPHABET INC.      2015-12-31  1.474610e+11          NaN
#
# measure_tag  ProfitLoss      Revenues  SalesRevenueNet
# 4639                NaN  9.027200e+10              NaN
# 4640                NaN  1.108550e+11              NaN
# 4641                NaN           NaN              NaN
# 4642                NaN  6.600100e+10              NaN
# 4643                NaN  7.498900e+10              NaN

# %%
over_100[over_100['company_name'] == 'AMAZON COM INC']
# Out:
# measure_tag    company_name period_end_date        Assets  GrossProfit  \
# 5106         AMAZON COM INC      2016-12-31  8.340200e+10          NaN
# 5113         AMAZON COM INC      2017-12-31  1.313100e+11          NaN
# 5114         AMAZON COM INC      2018-12-31  1.626480e+11          NaN
# 5115         AMAZON COM INC      2014-12-31  5.450500e+10          NaN
# 5116         AMAZON COM INC      2015-12-31  6.497933e+10          NaN
# 5118         AMAZON COM INC      2013-12-31  4.015900e+10          NaN
# 5120         AMAZON COM INC      2012-12-31  3.255500e+10          NaN
#
# measure_tag  ProfitLoss  Revenues  SalesRevenueNet
# 5106                NaN       NaN     8.986400e+10
# 5113                NaN       NaN     1.191595e+11
# 5114                NaN       NaN              NaN
# 5115                NaN       NaN     6.512400e+10
# 5116                NaN       NaN     7.850240e+10
# 5118                NaN       NaN     5.490600e+10
# 5120                NaN       NaN     4.781800e+10

# %%
over_100[(over_100['Revenues'].isna() ) & (over_100['SalesRevenueNet'].isna() ) ]
# Out:
# measure_tag                            company_name period_end_date  \
# 21           1347 PROPERTY INSURANCE HOLDINGS, INC.      2018-12-31
# 33                  1895 BANCORP OF WISCONSIN, INC.      2017-12-31
# 34                  1895 BANCORP OF WISCONSIN, INC.      2018-12-31
# 38                     1ST CENTURY BANCSHARES, INC.      2014-12-31
# 39                     1ST CENTURY BANCSHARES, INC.      2015-12-31
# ...                                             ...             ...
# 110930                                 ZULILY, INC.      2014-12-31
# 110932                                 ZULILY, INC.      2013-12-31
# 110945                               ZYMEWORKS INC.      2017-12-31
# 110946                               ZYMEWORKS INC.      2018-12-31
# 110983                                    ZYNGA INC      2018-12-31
#
# measure_tag        Assets  GrossProfit  ProfitLoss  Revenues  SalesRevenueNet
# 21           1.479230e+08          NaN         NaN       NaN              NaN
# 33           4.683610e+08          NaN   1659000.0       NaN              NaN
# 34           4.810990e+08          NaN    -19000.0       NaN              NaN
# 38           5.852180e+08          NaN         NaN       NaN              NaN
# 39           7.319500e+08          NaN         NaN       NaN              NaN
# ...                   ...          ...         ...       ...              ...
# 110930       4.923780e+08  212756500.0         NaN       NaN              NaN
# 110932       3.560870e+08  130883000.0         NaN       NaN              NaN
# 110945       1.319550e+08          NaN -10406000.0       NaN              NaN
# 110946       2.443630e+08          NaN -36556000.0       NaN              NaN
# 110983       2.146703e+09          NaN  15457000.0       NaN              NaN
#
# [8807 rows x 7 columns]

# %%
###################

# %%
# Examine companies with many blank fields

query = """
SELECT *
FROM sec_wide_all
WHERE  period_end_date < '2019-01-01' 
;
"""

sec_data = pd_sql.read_sql(query, connection)
sec_data.head()
# Out:
#             company_name             period_end_date     submission_number  \
# 0           'MKTG, INC.'  2014-03-31 00:00:00.000000  0001019056-14-000881
# 1       024 PHARMA, INC.  2015-12-31 00:00:00.000000  0001683168-17-000653
# 2       024 PHARMA, INC.  2016-12-31 00:00:00.000000  0001683168-17-000653
# 3  1 800 FLOWERS COM INC  2014-06-30 00:00:00.000000  0001437749-14-016921
# 4  1 800 FLOWERS COM INC  2014-06-30 00:00:00.000000  0001437749-15-017184
#
#   central_index_key        ein   sic  fiscal_year_end  fiscal_year  form  \
# 0            886475  061340408  7310              331         2013  10-K
# 1           1307969  201862731  3089             1231         2016  10-K
# 2           1307969  201862731  3089             1231         2016  10-K
# 3           1084869  113117311  5990              630         2014  10-K
# 4           1084869  113117311  5990              630         2015  10-K
#
#                    date_filed  ...  OperatingIncomeLoss  ProfitLoss  \
# 0  2014-06-27 00:00:00.000000  ...            2830011.0   2293272.0
# 1  2017-03-24 00:00:00.000000  ...                  NaN         NaN
# 2  2017-03-24 00:00:00.000000  ...                  NaN         NaN
# 3  2014-09-12 00:00:00.000000  ...           23706000.0  14675000.0
# 4  2015-09-11 00:00:00.000000  ...           23706000.0  14675000.0
#
#    RepaymentsOfLongTermDebt   Revenues  SalesRevenueNet  StockholdersEquity  \
# 0                       NaN        NaN              NaN          12190322.0
# 1                       NaN        NaN              NaN            137994.0
# 2                       NaN  1079541.0              NaN            759035.0
# 3                       NaN        NaN      756345000.0         183199000.0
# 4                       NaN        NaN      756345000.0         183228000.0
#
#    TotalAsset                   Industry  div_code       Division
# 0         NaN       Services-Advertising        73       Services
# 1         NaN     Plastics Products, NEC        30  Manufacturing
# 2         NaN     Plastics Products, NEC        30  Manufacturing
# 3         NaN  Retail-Retail Stores, NEC        59   Retail Trade
# 4         NaN  Retail-Retail Stores, NEC        59   Retail Trade
#
# [5 rows x 47 columns]

# %%
sec_data.columns
# Out:
# Index(['company_name', 'period_end_date', 'submission_number',
#        'central_index_key', 'ein', 'sic', 'fiscal_year_end', 'fiscal_year',
#        'form', 'date_filed', 'Assets', 'AssetsCurrent',
#        'CashAndCashEquivalentsAtCarryingValue',
#        'CashAndCashEquivalentsPeriodIncreaseDecrease', 'CommonStockValue',
#        'CostsAndExpenses', 'CurrentAsset', 'DeferredIncomeTaxExpenseBenefit',
#        'DeferredIncomeTaxLiabilities', 'DeferredIncomeTaxLiabilitiesNet',
#        'DeferredIncomeTaxesAndTaxCredits', 'Depreciation',
#        'EarningsPerShareBasic', 'EarningsPerShareDiluted', 'GrossProfit',
#        'Liabilities', 'LiabilitiesAndStockholdersEquity', 'LiabilitiesCurrent',
#        'LongTermDebt', 'LongTermDebtCurrent',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths',
#        'LongTermDebtNoncurrent', 'NetCashProvidedByUsedInFinancingActivities',
#        'NetCashProvidedByUsedInInvestingActivities',
#        'NetCashProvidedByUsedInOperatingActivities', 'NetIncomeLoss',
#        'OperatingExpenses', 'OperatingIncomeLoss', 'ProfitLoss',
#        'RepaymentsOfLongTermDebt', 'Revenues', 'SalesRevenueNet',
#        'StockholdersEquity', 'TotalAsset', 'Industry', 'div_code', 'Division'],
#       dtype='object')

# %%
sec_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173062 entries, 0 to 173061
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   company_name                                                   173062 non-null  object
#  1   period_end_date                                                173062 non-null  object
#  2   submission_number                                              173062 non-null  object
#  3   central_index_key                                              173062 non-null  object
#  4   ein                                                            173062 non-null  object
#  5   sic                                                            173062 non-null  object
#  6   fiscal_year_end                                                173062 non-null  int64
#  7   fiscal_year                                                    173062 non-null  int64
#  8   form                                                           173062 non-null  object
#  9   date_filed                                                     173062 non-null  object
#  10  Assets                                                         60326 non-null   float64
#  11  AssetsCurrent                                                  45081 non-null   float64
#  12  CashAndCashEquivalentsAtCarryingValue                          71473 non-null   float64
#  13  CashAndCashEquivalentsPeriodIncreaseDecrease                   53781 non-null   float64
#  14  CommonStockValue                                               47936 non-null   float64
#  15  CostsAndExpenses                                               18865 non-null   float64
#  16  CurrentAsset                                                   2 non-null       float64
#  17  DeferredIncomeTaxExpenseBenefit                                42191 non-null   float64
#  18  DeferredIncomeTaxLiabilities                                   23273 non-null   float64
#  19  DeferredIncomeTaxLiabilitiesNet                                3553 non-null    float64
#  20  DeferredIncomeTaxesAndTaxCredits                               6856 non-null    float64
#  21  Depreciation                                                   37466 non-null   float64
#  22  EarningsPerShareBasic                                          100720 non-null  float64
#  23  EarningsPerShareDiluted                                        99961 non-null   float64
#  24  GrossProfit                                                    63262 non-null   float64
#  25  Liabilities                                                    45844 non-null   float64
#  26  LiabilitiesAndStockholdersEquity                               57769 non-null   float64
#  27  LiabilitiesCurrent                                             45099 non-null   float64
#  28  LongTermDebt                                                   16987 non-null   float64
#  29  LongTermDebtCurrent                                            13041 non-null   float64
#  30  LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths  9351 non-null    float64
#  31  LongTermDebtNoncurrent                                         16135 non-null   float64
#  32  NetCashProvidedByUsedInFinancingActivities                     47641 non-null   float64
#  33  NetCashProvidedByUsedInInvestingActivities                     43813 non-null   float64
#  34  NetCashProvidedByUsedInOperatingActivities                     48686 non-null   float64
#  35  NetIncomeLoss                                                  137143 non-null  float64
#  36  OperatingExpenses                                              44769 non-null   float64
#  37  OperatingIncomeLoss                                            93392 non-null   float64
#  38  ProfitLoss                                                     47578 non-null   float64
#  39  RepaymentsOfLongTermDebt                                       18036 non-null   float64
#  40  Revenues                                                       66338 non-null   float64
#  41  SalesRevenueNet                                                37841 non-null   float64
#  42  StockholdersEquity                                             69791 non-null   float64
#  43  TotalAsset                                                     7 non-null       float64
#  44  Industry                                                       173062 non-null  object
#  45  div_code                                                       173062 non-null  object
#  46  Division                                                       173062 non-null  object
# dtypes: float64(34), int64(2), object(11)
# memory usage: 62.1+ MB

# %%
# look at companies who don't have "Assets" filled in, determine if company using another field
sec_data[sec_data['Assets'].isna()].company_name.unique()
# Out:
# array(['024 PHARMA, INC.', '1 800 FLOWERS COM INC', '12 RETECH CORP', ...,
#        'ZYNEX INC', 'ZYNGA INC', 'ZZLL INFORMATION TECHNOLOGY, INC'],
#       dtype=object)

# %%
examine_one = sec_data[sec_data['company_name']=='ZYNGA INC'].sort_values(by='period_end_date')
examine_one.to_excel('examine_one_co.xlsx', index=False)

# ZYNGA keeps re-submitting the annual report for a previous end_date.  Not different data, 
# just less data than originally submitted

# %%
# will examine another company
examine_two = sec_data[sec_data['company_name']=='ZZLL INFORMATION TECHNOLOGY, INC'].sort_values(by='period_end_date')
examine_two.to_excel('examine_two_co.xlsx', index=False)

## ZZLL submitted updated information

# %%
# 12 RETECH CORP

examine_3 = sec_data[sec_data['company_name']=='12 RETECH CORP'].sort_values(by='period_end_date')
examine_3.to_excel('examine_3_co.xlsx', index=False)

# resubmitting prior period_end the following year but not submitting new informaton.
