# %%
"""
query SEC data cleaned and prepared for 2019 and saved in postgres db

Merge with prepared bankruptcy list

TEST HOLD OUT DATA
"""

# %%
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as pd_sql
import numpy as np
import datetime

# %%
from pandasql import sqldf
# PandaSQL needs to be able to reference the global variables already defined (namely, `df`)
pysqldf = lambda q: sqldf(q, globals())

# %%
# Postgres info to connect

connection_args = {
    'host': 'localhost',  
    'dbname': 'bankruptcy',  
    'port': 5432          
}

connection = pg.connect(**connection_args)
connection.autocommit = True

# %%
# few fields for first initial model
# all 2019 data held out for test set

query = """
SELECT *
FROM sec_prep_2019
;
"""

sec_data = pd_sql.read_sql(query, connection)
sec_data.head()
# Out:
#                              company_name period_end_date  number_of_quarters  \
# 0                   1 800 FLOWERS COM INC      2019-06-30                   4
# 1                      10X GENOMICS, INC.      2019-12-31                   4
# 2  1347 PROPERTY INSURANCE HOLDINGS, INC.      2019-12-31                   4
# 3         1895 BANCORP OF WISCONSIN, INC.      2019-12-31                   4
# 4                    1LIFE HEALTHCARE INC      2019-12-31                   4
#
#       submission_number central_index_key        ein   sic  fiscal_year_end  \
# 0  0001437749-19-018360           1084869  113117311  5990            630.0
# 1  0001193125-20-052640           1770787  455614458  3826              NaN
# 2  0001493152-20-005206           1591890  461119100  6331              NaN
# 3  0001564590-20-014188           1751692  000000000  6036              NaN
# 4  0001564590-20-013666           1404123  760707204  8011              NaN
#
#   fiscal_year  form  ... InterestExpense  InventoryNet  SalesRevenueGoodsNet  \
# 0        2019  10-K  ...             NaN           NaN                   NaN
# 1        2019  10-K  ...    2.099667e+06    11920000.0                   NaN
# 2        2019  10-K  ...             NaN           NaN                   NaN
# 3        2019  10-K  ...    4.583000e+06           NaN                   NaN
# 4        2019  10-K  ...    7.040000e+05     3521500.0                   NaN
#
#    WorkingCapital   Revenue_any  SIC Code  \
# 0             NaN           NaN      5990
# 1             NaN  1.544303e+08      3826
# 2             NaN           NaN      6331
# 3             NaN           NaN      6036
# 4             NaN           NaN      8011
#
#                                             Industry Unnamed: 2  div_code  \
# 0                          Retail-Retail Stores, NEC       None        59
# 1                  Laboratory Analytical Instruments       None        38
# 2                  Fire, Marine & Casualty Insurance       None        63
# 3      Savings Institutions, Not Federally Chartered       None        60
# 4  Services-Offices & Clinics of Doctors of Medicine       None        80
#
#                              Division
# 0                        Retail Trade
# 1                       Manufacturing
# 2  Finance, Insurance and Real Estate
# 3  Finance, Insurance and Real Estate
# 4                            Services
#
# [5 rows x 56 columns]

# %%
sec_data.columns
# Out:
# Index(['company_name', 'period_end_date', 'number_of_quarters',
#        'submission_number', 'central_index_key', 'ein', 'sic',
#        'fiscal_year_end', 'fiscal_year', 'form', 'date_filed', 'Assets',
#        'AssetsCurrent', 'CashAndCashEquivalentsAtCarryingValue',
#        'CashAndCashEquivalentsPeriodIncreaseDecrease', 'CommonStockValue',
#        'CostsAndExpenses', 'CurrentAsset', 'DeferredIncomeTaxExpenseBenefit',
#        'DeferredIncomeTaxLiabilities', 'DeferredIncomeTaxLiabilitiesNet',
#        'DeferredIncomeTaxesAndTaxCredits', 'Depreciation',
#        'EarningsPerShareBasic', 'EarningsPerShareDiluted', 'GrossProfit',
#        'Liabilities', 'LiabilitiesAndStockholdersEquity', 'LiabilitiesCurrent',
#        'LongTermDebt', 'LongTermDebtCurrent',
#        'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths',
#        'LongTermDebtNoncurrent', 'NetCashProvidedByUsedInFinancingActivities',
#        'NetCashProvidedByUsedInInvestingActivities',
#        'NetCashProvidedByUsedInOperatingActivities', 'NetIncomeLoss',
#        'OperatingExpenses', 'OperatingIncomeLoss', 'ProfitLoss',
#        'RepaymentsOfLongTermDebt', 'Revenues', 'SalesRevenueNet',
#        'StockholdersEquity', 'Goodwill', 'IncreaseDecreaseInInventories',
#        'InterestExpense', 'InventoryNet', 'SalesRevenueGoodsNet',
#        'WorkingCapital', 'Revenue_any', 'SIC Code', 'Industry', 'Unnamed: 2',
#        'div_code', 'Division'],
#       dtype='object')

# %%
sec_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3485 entries, 0 to 3484
# Data columns (total 56 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   company_name                                                   3485 non-null   object
#  1   period_end_date                                                3485 non-null   datetime64[ns]
#  2   number_of_quarters                                             3485 non-null   int64
#  3   submission_number                                              3485 non-null   object
#  4   central_index_key                                              3485 non-null   object
#  5   ein                                                            3485 non-null   object
#  6   sic                                                            3485 non-null   object
#  7   fiscal_year_end                                                408 non-null    float64
#  8   fiscal_year                                                    3485 non-null   object
#  9   form                                                           3485 non-null   object
#  10  date_filed                                                     3485 non-null   object
#  11  Assets                                                         3485 non-null   float64
#  12  AssetsCurrent                                                  2479 non-null   float64
#  13  CashAndCashEquivalentsAtCarryingValue                          3060 non-null   float64
#  14  CashAndCashEquivalentsPeriodIncreaseDecrease                   656 non-null    float64
#  15  CommonStockValue                                               2671 non-null   float64
#  16  CostsAndExpenses                                               941 non-null    float64
#  17  CurrentAsset                                                   0 non-null      object
#  18  DeferredIncomeTaxExpenseBenefit                                2752 non-null   float64
#  19  DeferredIncomeTaxLiabilities                                   2368 non-null   float64
#  20  DeferredIncomeTaxLiabilitiesNet                                1032 non-null   float64
#  21  DeferredIncomeTaxesAndTaxCredits                               533 non-null    float64
#  22  Depreciation                                                   2010 non-null   float64
#  23  EarningsPerShareBasic                                          2496 non-null   float64
#  24  EarningsPerShareDiluted                                        2461 non-null   float64
#  25  GrossProfit                                                    1225 non-null   float64
#  26  Liabilities                                                    3408 non-null   float64
#  27  LiabilitiesAndStockholdersEquity                               3468 non-null   float64
#  28  LiabilitiesCurrent                                             2476 non-null   float64
#  29  LongTermDebt                                                   1588 non-null   float64
#  30  LongTermDebtCurrent                                            1058 non-null   float64
#  31  LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths  1421 non-null   float64
#  32  LongTermDebtNoncurrent                                         1368 non-null   float64
#  33  NetCashProvidedByUsedInFinancingActivities                     3364 non-null   float64
#  34  NetCashProvidedByUsedInInvestingActivities                     3340 non-null   float64
#  35  NetCashProvidedByUsedInOperatingActivities                     3361 non-null   float64
#  36  NetIncomeLoss                                                  3173 non-null   float64
#  37  OperatingExpenses                                              1183 non-null   float64
#  38  OperatingIncomeLoss                                            2509 non-null   float64
#  39  ProfitLoss                                                     1922 non-null   float64
#  40  RepaymentsOfLongTermDebt                                       1155 non-null   float64
#  41  Revenues                                                       1385 non-null   float64
#  42  SalesRevenueNet                                                11 non-null     float64
#  43  StockholdersEquity                                             3395 non-null   float64
#  44  Goodwill                                                       2055 non-null   float64
#  45  IncreaseDecreaseInInventories                                  1278 non-null   float64
#  46  InterestExpense                                                2116 non-null   float64
#  47  InventoryNet                                                   1298 non-null   float64
#  48  SalesRevenueGoodsNet                                           1 non-null      float64
#  49  WorkingCapital                                                 39 non-null     float64
#  50  Revenue_any                                                    1392 non-null   float64
#  51  SIC Code                                                       3485 non-null   object
#  52  Industry                                                       3485 non-null   object
#  53  Unnamed: 2                                                     0 non-null      object
#  54  div_code                                                       3485 non-null   object
#  55  Division                                                       3485 non-null   object
# dtypes: datetime64[ns](1), float64(40), int64(1), object(14)
# memory usage: 1.5+ MB

# %%
sec_data.shape
# Out:
# (3485, 56)

# %%
# add the labels for the target
# sheet LIST contains 2015-2019 bankruptcies where company names where adjusted 
# to be exactly like in SEC filings

brd_list = pd.read_excel('debtor_list_ein_lookup.xlsx', sheet_name='FULL_LIST')
#brd_labels

# %%
brd_list['FULL_NAME'] = brd_list['name_in_sec_data'].str.upper()
brd_list['bankruptcy_date'] = brd_list['date_filed']
brd_list.head()
# Out:
#                             debtor_name date_filed chapter_filing  \
# 0                 First Mariner Bancorp 2014-02-10     Chapter 11
# 1                             USEC Inc. 2014-03-05     Chapter 11
# 2     Global Geophysical Services, Inc. 2014-03-25     Chapter 11
# 3              James River Coal Company 2014-04-07     Chapter 11
# 4  Momentive Performance Materials Inc. 2014-04-13     Chapter 11
#
#                        name_in_sec_data  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                 First Mariner Bancorp         NaN         NaN         NaN
# 1                              USEC INC         NaN         NaN         NaN
# 2       GLOBAL GEOPHYSICAL SERVICES INC         NaN         NaN         NaN
# 3      JAMES RIVER GROUP HOLDINGS, LTD.         NaN         NaN         NaN
# 4  Momentive Performance Materials Inc.         NaN         NaN         NaN
#
#                               FULL_NAME bankruptcy_date
# 0                 FIRST MARINER BANCORP      2014-02-10
# 1                              USEC INC      2014-03-05
# 2       GLOBAL GEOPHYSICAL SERVICES INC      2014-03-25
# 3      JAMES RIVER GROUP HOLDINGS, LTD.      2014-04-07
# 4  MOMENTIVE PERFORMANCE MATERIALS INC.      2014-04-13

# %%
brd_list.shape
# Out:
# (201, 9)

# %%
brd_list['FULL_NAME'].nunique()
# Out:
# 194

# %%
# Chaparral Energy filed in 2016 and 2020
# Ultra Petroleum Corp filed in 2016 and 2020
# American Apparel
# Geophysical
# Halcon Resources
# Paragon Offshore

# %%
brd_labels = brd_list[['FULL_NAME', 'bankruptcy_date']]

# %%
add_brd = pd.merge(sec_data, brd_labels, how='left', left_on='company_name', right_on='FULL_NAME')

# %%
add_brd.head()
# Out:
#                              company_name period_end_date  number_of_quarters  \
# 0                   1 800 FLOWERS COM INC      2019-06-30                   4
# 1                      10X GENOMICS, INC.      2019-12-31                   4
# 2  1347 PROPERTY INSURANCE HOLDINGS, INC.      2019-12-31                   4
# 3         1895 BANCORP OF WISCONSIN, INC.      2019-12-31                   4
# 4                    1LIFE HEALTHCARE INC      2019-12-31                   4
#
#       submission_number central_index_key        ein   sic  fiscal_year_end  \
# 0  0001437749-19-018360           1084869  113117311  5990            630.0
# 1  0001193125-20-052640           1770787  455614458  3826              NaN
# 2  0001493152-20-005206           1591890  461119100  6331              NaN
# 3  0001564590-20-014188           1751692  000000000  6036              NaN
# 4  0001564590-20-013666           1404123  760707204  8011              NaN
#
#   fiscal_year  form  ... SalesRevenueGoodsNet  WorkingCapital   Revenue_any  \
# 0        2019  10-K  ...                  NaN             NaN           NaN
# 1        2019  10-K  ...                  NaN             NaN  1.544303e+08
# 2        2019  10-K  ...                  NaN             NaN           NaN
# 3        2019  10-K  ...                  NaN             NaN           NaN
# 4        2019  10-K  ...                  NaN             NaN           NaN
#
#    SIC Code                                           Industry  Unnamed: 2  \
# 0      5990                          Retail-Retail Stores, NEC        None
# 1      3826                  Laboratory Analytical Instruments        None
# 2      6331                  Fire, Marine & Casualty Insurance        None
# 3      6036      Savings Institutions, Not Federally Chartered        None
# 4      8011  Services-Offices & Clinics of Doctors of Medicine        None
#
#    div_code                            Division  FULL_NAME  bankruptcy_date
# 0        59                        Retail Trade        NaN              NaT
# 1        38                       Manufacturing        NaN              NaT
# 2        63  Finance, Insurance and Real Estate        NaN              NaT
# 3        60  Finance, Insurance and Real Estate        NaN              NaT
# 4        80                            Services        NaN              NaT
#
# [5 rows x 58 columns]

# %%
add_brd.shape
# Out:
# (3487, 58)

# %%
add_brd[add_brd['bankruptcy_date'].notnull()].head()
# Out:
#                       company_name period_end_date  number_of_quarters  \
# 104                      AKORN INC      2019-12-31                   4
# 147  ALTA MESA RESOURCES, INC. /DE      2019-12-31                   4
# 259                  ARCH COAL INC      2019-12-31                   4
# 287      ASCENA RETAIL GROUP, INC.      2019-07-31                   4
# 461     BONANZA CREEK ENERGY, INC.      2019-12-31                   4
#
#         submission_number central_index_key        ein   sic  fiscal_year_end  \
# 104  0001628280-20-002314              3116  720717400  2834              NaN
# 147  0001690769-20-000032           1690769  814433840  1311              NaN
# 259  0001628280-20-001344           1037676  430921172  1221              NaN
# 287  0001498301-19-000092           1498301  300641353  5600              NaN
# 461  0001509589-20-000011           1509589  611630631  1311              NaN
#
#     fiscal_year  form  ... SalesRevenueGoodsNet  WorkingCapital   Revenue_any  \
# 104        2019  10-K  ...                  NaN    -505500000.0           NaN
# 147        2019  10-K  ...                  NaN             NaN  3.735388e+08
# 259        2019  10-K  ...                  NaN             NaN           NaN
# 287        2019  10-K  ...                  NaN             NaN  5.559033e+09
# 461        2019  10-K  ...                  NaN             NaN           NaN
#
#      SIC Code                                  Industry  Unnamed: 2  div_code  \
# 104      2834               Pharmaceutical Preparations        None        28
# 147      1311             Crude Petroleum & Natural Gas        None        13
# 259      1221  Bituminous Coal & Lignite Surface Mining        None        12
# 287      5600         Retail-Apparel & Accessory Stores        None        56
# 461      1311             Crude Petroleum & Natural Gas        None        13
#
#           Division                      FULL_NAME  bankruptcy_date
# 104  Manufacturing                      AKORN INC       2020-05-20
# 147         Mining  ALTA MESA RESOURCES, INC. /DE       2019-09-11
# 259         Mining                  ARCH COAL INC       2016-01-11
# 287   Retail Trade      ASCENA RETAIL GROUP, INC.       2020-07-23
# 461         Mining     BONANZA CREEK ENERGY, INC.       2017-01-04
#
# [5 rows x 58 columns]

# %%
#add_brd.info()

# %%
#put back to a datetime variable

add_brd['period_end_date'] = pd.to_datetime(add_brd['period_end_date'])

# %%
## if bankruptcy date is within 1 year of period_end_date , then target = 1

## add column that calculates difference in 2 dates

add_brd['time_delta'] =  add_brd['bankruptcy_date'] - add_brd['period_end_date'] 
add_brd['days'] = add_brd["time_delta"].dt.days
add_brd.head()
# Out:
#                              company_name period_end_date  number_of_quarters  \
# 0                   1 800 FLOWERS COM INC      2019-06-30                   4
# 1                      10X GENOMICS, INC.      2019-12-31                   4
# 2  1347 PROPERTY INSURANCE HOLDINGS, INC.      2019-12-31                   4
# 3         1895 BANCORP OF WISCONSIN, INC.      2019-12-31                   4
# 4                    1LIFE HEALTHCARE INC      2019-12-31                   4
#
#       submission_number central_index_key        ein   sic  fiscal_year_end  \
# 0  0001437749-19-018360           1084869  113117311  5990            630.0
# 1  0001193125-20-052640           1770787  455614458  3826              NaN
# 2  0001493152-20-005206           1591890  461119100  6331              NaN
# 3  0001564590-20-014188           1751692  000000000  6036              NaN
# 4  0001564590-20-013666           1404123  760707204  8011              NaN
#
#   fiscal_year  form  ...   Revenue_any  SIC Code  \
# 0        2019  10-K  ...           NaN      5990
# 1        2019  10-K  ...  1.544303e+08      3826
# 2        2019  10-K  ...           NaN      6331
# 3        2019  10-K  ...           NaN      6036
# 4        2019  10-K  ...           NaN      8011
#
#                                             Industry  Unnamed: 2  div_code  \
# 0                          Retail-Retail Stores, NEC        None        59
# 1                  Laboratory Analytical Instruments        None        38
# 2                  Fire, Marine & Casualty Insurance        None        63
# 3      Savings Institutions, Not Federally Chartered        None        60
# 4  Services-Offices & Clinics of Doctors of Medicine        None        80
#
#                              Division  FULL_NAME bankruptcy_date  time_delta  \
# 0                        Retail Trade        NaN             NaT         NaT
# 1                       Manufacturing        NaN             NaT         NaT
# 2  Finance, Insurance and Real Estate        NaN             NaT         NaT
# 3  Finance, Insurance and Real Estate        NaN             NaT         NaT
# 4                            Services        NaN             NaT         NaT
#
#    days
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 60 columns]

# %%
#add_brd['target'] = np.where((add_brd['days'] >= 0) & (add_brd['days'] <=365) , 1, 0)
add_brd['target'] = np.where(add_brd['bankruptcy_date'] >= datetime.datetime(2020,1,1), 1, 0)

# %%
add_brd[add_brd['bankruptcy_date'].notnull()].head()
# Out:
#                       company_name period_end_date  number_of_quarters  \
# 104                      AKORN INC      2019-12-31                   4
# 147  ALTA MESA RESOURCES, INC. /DE      2019-12-31                   4
# 259                  ARCH COAL INC      2019-12-31                   4
# 287      ASCENA RETAIL GROUP, INC.      2019-07-31                   4
# 461     BONANZA CREEK ENERGY, INC.      2019-12-31                   4
#
#         submission_number central_index_key        ein   sic  fiscal_year_end  \
# 104  0001628280-20-002314              3116  720717400  2834              NaN
# 147  0001690769-20-000032           1690769  814433840  1311              NaN
# 259  0001628280-20-001344           1037676  430921172  1221              NaN
# 287  0001498301-19-000092           1498301  300641353  5600              NaN
# 461  0001509589-20-000011           1509589  611630631  1311              NaN
#
#     fiscal_year  form  ... SIC Code                                  Industry  \
# 104        2019  10-K  ...     2834               Pharmaceutical Preparations
# 147        2019  10-K  ...     1311             Crude Petroleum & Natural Gas
# 259        2019  10-K  ...     1221  Bituminous Coal & Lignite Surface Mining
# 287        2019  10-K  ...     5600         Retail-Apparel & Accessory Stores
# 461        2019  10-K  ...     1311             Crude Petroleum & Natural Gas
#
#      Unnamed: 2  div_code       Division                      FULL_NAME  \
# 104        None        28  Manufacturing                      AKORN INC
# 147        None        13         Mining  ALTA MESA RESOURCES, INC. /DE
# 259        None        12         Mining                  ARCH COAL INC
# 287        None        56   Retail Trade      ASCENA RETAIL GROUP, INC.
# 461        None        13         Mining     BONANZA CREEK ENERGY, INC.
#
#      bankruptcy_date time_delta    days  target
# 104       2020-05-20   141 days   141.0       1
# 147       2019-09-11  -111 days  -111.0       0
# 259       2016-01-11 -1450 days -1450.0       0
# 287       2020-07-23   358 days   358.0       1
# 461       2017-01-04 -1091 days -1091.0       0
#
# [5 rows x 61 columns]

# %%
add_brd[add_brd['target'] == 1].head()
# Out:
#                   company_name period_end_date  number_of_quarters  \
# 104                  AKORN INC      2019-12-31                   4
# 287  ASCENA RETAIL GROUP, INC.      2019-07-31                   4
# 482     BRIGGS & STRATTON CORP      2019-06-30                   4
# 537  CALIFORNIA RESOURCES CORP      2019-12-31                   4
# 565         CARBO CERAMICS INC      2019-12-31                   4
#
#         submission_number central_index_key        ein   sic  fiscal_year_end  \
# 104  0001628280-20-002314              3116  720717400  2834              NaN
# 287  0001498301-19-000092           1498301  300641353  5600              NaN
# 482  0000014195-19-000027             14195  390182330  3510            630.0
# 537  0001609253-20-000066           1609253  465670947  1311              NaN
# 565  0001564590-20-025870           1009672  721100013  3290              NaN
#
#     fiscal_year  form  ... SIC Code  \
# 104        2019  10-K  ...     2834
# 287        2019  10-K  ...     5600
# 482        2019  10-K  ...     3510
# 537        2019  10-K  ...     1311
# 565        2019  10-K  ...     3290
#
#                                               Industry  Unnamed: 2  div_code  \
# 104                        Pharmaceutical Preparations        None        28
# 287                  Retail-Apparel & Accessory Stores        None        56
# 482                                 Engines & Turbines        None        35
# 537                      Crude Petroleum & Natural Gas        None        13
# 565  Abrasive, Asbestos & Misc Nonmetallic Mineral ...        None        32
#
#           Division                  FULL_NAME  bankruptcy_date time_delta  \
# 104  Manufacturing                  AKORN INC       2020-05-20   141 days
# 287   Retail Trade  ASCENA RETAIL GROUP, INC.       2020-07-23   358 days
# 482  Manufacturing     BRIGGS & STRATTON CORP       2020-07-20   386 days
# 537         Mining  CALIFORNIA RESOURCES CORP       2020-07-15   197 days
# 565  Manufacturing         CARBO CERAMICS INC       2020-03-29    89 days
#
#       days  target
# 104  141.0       1
# 287  358.0       1
# 482  386.0       1
# 537  197.0       1
# 565   89.0       1
#
# [5 rows x 61 columns]

# %%
add_brd.target.value_counts()
# Out:
# 0    3439
# 1      48
# Name: target, dtype: int64

# %%
# Searched for filings in SEC EDGAR
# Three companies did not send a 2019 report to SEC

# Neiman Marcus
# Centric Brands
# AAC Holdings, INC

# %%
add_brd.company_name.nunique()
# Out:
# 3484

# %%
## examine further

add_brd.to_excel('review_test_df.xlsx', index=False)

# %%
# pickle the model_data df
import pickle

with open('test_data.pickle', 'wb') as to_write:
    pickle.dump(add_brd, to_write)
